# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import scipy
from scipy import misc, ndimage
from scipy.ndimage.interpolation import zoom
from scipy.ndimage import imread
from scipy.misc import imsave
from PIL import Image
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
IMGDIR = '../../data/VOCdevkit'
DATADIR = '/home/ubuntu/SSDcaffe/data/VOC0712'
TESTDIR = '../data/Test'

# %%
trn_imgs = os.listdir(os.path.join(IMGDIR, "VOC0712/JPEGImages"))
trn_annos = os.listdir(os.path.join(IMGDIR, "VOC0712/Annotations"))
print( len(trn_imgs), len(trn_annos))
trn_annos[:2]
# Out:
# (45434, 7198)
# ['187_71.xml', '200_23.xml']

# %%
os.path.join(DATADIR, 'trainval_fold1.csv')
# Out:
# '/home/ubuntu/SSDcaffe/data/VOC0712/trainval_fold1.csv'

# %% [markdown]
# ### Write out train and test files

# %%
tv_fold1 = open(os.path.join(DATADIR, 'trainval_fold1.txt'),'w')
for f in trn_annos:
    fname = f.split('.')[0]
    imgname = f.split('_')[0]
    if int(imgname) % 2 == 0 :
        tv_fold1.write('VOC0712/JPEGImages/%s.jpg VOC0712/Annotations/%s.xml\n'%(fname, fname))
tv_fold1.close()

tv_fold2 = open(os.path.join(DATADIR, 'trainval_fold2.txt'),'w')
for f in trn_annos:
    fname = f.split('.')[0]
    imgname = f.split('_')[0]
    if int(imgname) % 2 != 0 :
        tv_fold2.write('VOC0712/JPEGImages/%s.jpg VOC0712/Annotations/%s.xml\n'%(fname, fname))
tv_fold2.close()

ts_fold1 = open(os.path.join(DATADIR, 'test_fold1.txt'),'w')
for f in trn_annos:
    fname = f.split('.')[0]
    imgname = f.split('_')[0]
    if int(imgname) % 2 != 0 :
        ts_fold1.write('VOC0712/JPEGImages/%s.jpg VOC0712/Annotations/%s.xml\n'%(fname, fname))
ts_fold1.close()

ts_fold2 = open(os.path.join(DATADIR, 'test_fold2.txt'),'w')
for f in trn_annos:
    fname = f.split('.')[0]
    imgname = f.split('_')[0]
    if int(imgname) % 2 == 0 :
        ts_fold2.write('VOC0712/JPEGImages/%s.jpg VOC0712/Annotations/%s.xml\n'%(fname, fname))
ts_fold2.close()

# %%
trn_annos[:2]
# Out:
# ['187_71.xml', '200_23.xml']

# %% [markdown]
# ### Write out the full test file - only do it for the ones where we found a seal in rfcn

# %%
tv_all = open(os.path.join(DATADIR, 'trainval_all.txt'),'w')
for f in trn_annos:
    fname = f.split('.')[0]
    tv_all.write('VOC0712/JPEGImages/%s.jpg VOC0712/Annotations/%s.xml\n'%(fname, fname))
tv_all.close()

# %%
os.getcwd()
# Out:
# '/home/ubuntu/noaa/feat'

# %%
rfcn_pred = "../coords/resnet50TestPreds2604.csv"
rfcn_imgs = []
for c, row in enumerate(open(rfcn_pred)):
    if c == 0 :continue
    row = row.split(",")
    if float(row[1]) > 0.3 : 
       rfcn_imgs.append(row[0]) 
rfcn_imgs = set(rfcn_imgs)
print(len(rfcn_imgs))
# Out:
# 165721

# %%
ts_all = open(os.path.join(DATADIR, 'test_all.txt'),'w')
for f in rfcn_imgs:
    fname = f.split('.')[0]
    ts_all.write('JPEGImagesTest/%s.jpg VOC0712/Annotations/200_23.xml\n'%(fname))
ts_all.close()

# %% [markdown]
# ### Write out image sizes

# %%
ts_sz_fold2 = open(os.path.join(DATADIR, 'test_name_size_fold2.txt'),'w')
for f in trn_annos:
    fname = f.split('.')[0]
    imgname = f.split('_')[0]
    if int(imgname) % 2 == 0 :
        shp = imread('/home/ubuntu/data/VOCdevkit/VOC0712/JPEGImages/%s.jpg'%(fname)).shape
        ts_sz_fold2.write('%s %s %s\n'%(fname, shp[0], shp[1]))
ts_sz_fold2.close()

ts_sz_fold1 = open(os.path.join(DATADIR, 'test_name_size_fold1.txt'),'w')
for f in trn_annos:
    fname = f.split('.')[0]
    imgname = f.split('_')[0]
    if int(imgname) % 2 != 0 :
        shp = imread('/home/ubuntu/data/VOCdevkit/VOC0712/JPEGImages/%s.jpg'%(fname)).shape
        ts_sz_fold1.write('%s %s %s\n'%(fname, shp[0], shp[1]))
ts_sz_fold1.close()

# %%
ts_sz_all = open(os.path.join(DATADIR, 'test_name_size_all.txt'),'w')
for f in rfcn_imgs:
    fname = f
    #shp = imread('/home/ubuntu/noaa/darknet/seals/JPEGImagesTest/%s.jpg'%(fname)).shape
    shp = (544, 544)
    ts_sz_all.write('%s %s %s\n'%(fname, shp[0], shp[1]))
ts_sz_all.close()

# %% [markdown]
# ### Copy the annotations and images and replace annotations with ints for SSD

# %%
# Copy the directories
dir_from = "/home/ubuntu/py-R-FCN/data/VOCdevkit0712/VOC0712/"
dir_to = "/home/ubuntu/data/VOCdevkit/VOC0712"
import shutil
shutil.copytree(dir_from, dir_to)

# %%
# Replace floats with int in annotations
#!/usr/bin/env python3
import fileinput
textToSearch1 = ['.0</xmin>', '.0</ymin>', '.0</xmax>', '.0</ymax>']
textToSearch2 = ['.1</xmin>', '.1</ymin>', '.1</xmax>', '.1</ymax>']
textToSearch3 = ['.9</xmin>', '.9</ymin>', '.9</xmax>', '.9</ymax>']
textToReplace = ['</xmin>', '</ymin>', '</xmax>', '</ymax>']
trn_annos[:2]
# Out:
# ['187_71.xml', '200_23.xml']

# %%
dir_from = "/home/ubuntu/py-R-FCN/data/VOCdevkit0712/VOC0712/"
dir_to = "/home/ubuntu/data/VOCdevkit/VOC0712"
for f in trn_annos:
    fname = os.path.join(dir_to, "Annotations", f)
    # Read in the file
    with open(fname, 'r') as file :
      filedata = file.read()
    
    for i in range(4):
        filedata = filedata.replace(textToSearch1[i], textToReplace[i])
        filedata = filedata.replace(textToSearch2[i], textToReplace[i])
        filedata = filedata.replace(textToSearch3[i], textToReplace[i])

    filedata = filedata.replace('<folder>seals</folder>', '<folder>VOC0712</folder>')

        
    # Write the file out again
    with open(fname, 'w') as file:
      file.write(filedata)

# %%
import xmltodict
with open(os.path.join(dir_to, "Annotations", trn_annos[0])) as fd:
    doc = xmltodict.parse(fd.read())

# %%
print doc['annotation']['filename']
for seg in doc['annotation']['object'][:2]:
    print seg['name']
    print seg['bndbox']
# Out:
# 187_71.jpg
# seals
# OrderedDict([(u'xmin', u'0'), (u'ymin', u'153'), (u'xmax', u'43'), (u'ymax', u'203')])
# 0
# seals
# OrderedDict([(u'xmin', u'12'), (u'ymin', u'190'), (u'xmax', u'62'), (u'ymax', u'240')])
# 12
# seals
# OrderedDict([(u'xmin', u'13'), (u'ymin', u'464'), (u'xmax', u'63'), (u'ymax', u'514')])
# 13

# %%
def create_rect2(row):
    return plt.Rectangle((row[0], row[1]), row[2] - row[0], row[3] - row[1], color='red', fill=False, lw=2)
img = imread('/home/ubuntu/data/VOCdevkit/VOC0712/JPEGImages/%s'%(doc['annotation']['filename']))
plt.figure(figsize=(5,5))
plt.imshow(img)
for seg in doc['annotation']['object']:
    row = [seg['bndbox']['xmin'], seg['bndbox']['ymin'], seg['bndbox']['xmax'], seg['bndbox']['ymax']]
    row = [int(i) for i in row]
    plt.gca().add_patch(create_rect2(row))

# %%
import xmltodict
with open(os.path.join("/home/ubuntu/data/VOCdevkit/VOC2007_orig/Annotations/009926.xml")) as fd:
    doc = xmltodict.parse(fd.read())
img = imread('/home/ubuntu/data/VOCdevkit/VOC2007_orig/JPEGImages/%s'%(doc['annotation']['filename']))
plt.figure(figsize=(5,5))
plt.imshow(img)
for seg in doc['annotation']['object']:
    row = [seg['bndbox']['xmin'], seg['bndbox']['ymin'], seg['bndbox']['xmax'], seg['bndbox']['ymax']]
    row = [int(i) for i in row]
    plt.gca().add_patch(create_rect2(row))

# %% [markdown]
# ### Verify the SSD predictions
# ##### for fold1 411_03 is a good image to check

# %%
imgname = '411_03'#trn_imgs[10].split('.')[0]

# %%
frfcn = "../coords/comp4_30000_det_test_seals_fold1.txt"
fssd  = "../../data/VOCdevkit/results/backup/comp4_det_test_seals_300_nms0.7_fold1.txt"
#fssd = "/home/ubuntu/data/VOCdevkit/results/VOC2007/SSD_300x300_score/Main/comp4_det_test_seals.txt"
lrfcn = []
lssd = []
for c, row in enumerate(open(frfcn)):
    row = row.split(" ")
    if row[0] == imgname:
        row[1:] = [float(r.replace("\n", "")) for r in row[1:]]
        lrfcn.append(row) 
for c, row in enumerate(open(fssd)):
    row = row.split(" ")
    if row[0] == imgname:
        row[1:] = [float(r.replace("\n", "")) for r in row[1:]]
        lssd.append(row) 
print(len(lrfcn), len(lssd))
# Out:
# (67, 104)

# %%
img = imread('/home/ubuntu/data/VOCdevkit/VOC0712/JPEGImages/%s.jpg'%(imgname))
plt.figure(figsize=(10,10))
plt.imshow(img)
for seg in lrfcn:
    if float(seg[1])>0.2:
        row = [seg[2], seg[3], seg[4], seg[5] ]
        row = [int(i) for i in row]
        plt.gca().add_patch(create_rect2(row))

# %%
plt.figure(figsize=(7,7))
plt.imshow(img)
for seg in lssd:
    if float(seg[1])>0.2:
        row = [seg[2], seg[3], seg[4], seg[5] ]
        row = [int(i) for i in row]
        plt.gca().add_patch(create_rect2(row))

# %%
imgname = '5838_21'
fssd  = "../../data/VOCdevkit/results/VOC2007/SSD_300x300_score/Main/comp4_det_test_seals.txt"
lssd = []
for c, row in enumerate(open(fssd)):
    row = row.split(" ")
    if row[0] == imgname:
        row[1:] = [float(r.replace("\n", "")) for r in row[1:]]
        lssd.append(row) 
img = imread('/home/ubuntu/data/VOCdevkit/JPEGImagesTest/%s.jpg'%(imgname))
plt.figure(figsize=(5,5))
plt.imshow(img)
for seg in lssd:
    if float(seg[1])>0.2:
        row = [seg[2], seg[3], seg[4], seg[5] ]
        row = [int(i) for i in row]
        plt.gca().add_patch(create_rect2(row))
