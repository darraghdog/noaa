# %%
import os, gc, gzip
import numpy as np
import math
import pandas as pd
from keras import backend as K
from keras.layers import Input, MaxPooling2D, UpSampling2D, Conv2D
#from keras.layers import concatenate
#from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from keras.models import Model
from keras.optimizers import Adam
from skimage.transform import resize
from skimage.io import imsave, imread
from skimage.transform import resize 
#from seg_noaa import load_train_data, load_test_data
from segmodels import dice_coef, dice_coef_loss, double_conv_layer
from segmodels import create_model, preprocess_img, preprocess, test_generator
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dropout, Activation
from keras import backend as K
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline 

smooth = 1.

gc.collect()
# Out:
# Using Theano backend.
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5103)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)
# 1169

# %%
img_rows = 448#320#512
img_cols = 448#320#512
batch_size = 16
nb_epoch = 5 #25
print(img_rows, img_cols)
data_path = '/home/ubuntu/noaa/darknet/seals/'
train_data_path = os.path.join(data_path, 'JPEGImagesBlk')
mask_data_path = '/home/ubuntu/noaa/data/mask/classesBoost'
smooth = 1.
K.image_dim_ordering()
classes = 5
OUTPUT_MASK_CHANNELS = 5
# Out:
# (320, 320)

# %%
def chunks(l, n):
    n = max(1, n)
    return (l[i:i+n] for i in xrange(0, len(l), n))

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)


def double_conv_layer(x, size, dropout, batch_norm):
    conv = Convolution2D(size, 3, 3, border_mode='same')(x)
    if batch_norm == True:
        conv = BatchNormalization(mode=0, axis=1)(conv)
    conv = Activation('relu')(conv)
    conv = Convolution2D(size, 3, 3, border_mode='same')(conv)
    if batch_norm == True:
        conv = BatchNormalization(mode=0, axis=1)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = Dropout(dropout)(conv)
    return conv


def create_model(dropout_val=0.05, batch_norm=True):
    inputs = Input((3, img_rows, img_cols))
    conv1 = double_conv_layer(inputs, 32, dropout_val, batch_norm)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = double_conv_layer(pool1, 64, dropout_val, batch_norm)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = double_conv_layer(pool2, 128, dropout_val, batch_norm)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = double_conv_layer(pool3, 256, dropout_val, batch_norm)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = double_conv_layer(pool4, 512, dropout_val, batch_norm)
    pool5 = MaxPooling2D(pool_size=(2, 2))(conv5)

    conv6 = double_conv_layer(pool5, 1024, dropout_val, batch_norm)

    up6 = merge([UpSampling2D(size=(2, 2))(conv6), conv5], mode='concat', concat_axis=1)
    conv7 = double_conv_layer(up6, 512, dropout_val, batch_norm)

    up7 = merge([UpSampling2D(size=(2, 2))(conv7), conv4], mode='concat', concat_axis=1)
    conv8 = double_conv_layer(up7, 256, dropout_val, batch_norm)

    up8 = merge([UpSampling2D(size=(2, 2))(conv8), conv3], mode='concat', concat_axis=1)
    conv9 = double_conv_layer(up8, 128, dropout_val, batch_norm)

    up9 = merge([UpSampling2D(size=(2, 2))(conv9), conv2], mode='concat', concat_axis=1)
    conv10 = double_conv_layer(up9, 64, dropout_val, batch_norm)

    up10 = merge([UpSampling2D(size=(2, 2))(conv10), conv1], mode='concat', concat_axis=1)
    conv11 = double_conv_layer(up10, 32, 0, batch_norm)

    conv12 = Convolution2D(OUTPUT_MASK_CHANNELS, 1, 1)(conv11)
    conv12 = BatchNormalization(mode=0, axis=1)(conv12)
    conv12 = Activation('sigmoid')(conv12)

    model = Model(input=inputs, output=conv12)
    return model

def preprocess_img(imgs):
    imgs_p = np.ndarray((imgs.shape[0], img_rows, img_cols, 3), dtype=np.float64)
    for i in range(imgs.shape[0]):
        imgs_p[i] = resize(imgs[i], (img_cols, img_rows, 3), preserve_range=True)

    imgs_p = imgs_p[..., np.newaxis]
    return imgs_p

def preprocess_mask(imgs, channels=5):
    imgs_p = np.ndarray((imgs.shape[0], img_rows, img_cols, channels), dtype=np.uint8)
    for i in range(imgs.shape[0]):
        imgs_p[i] = multi_resize(imgs[i])

    imgs_p = imgs_p[..., np.newaxis]
    return imgs_p

def show_mask(img):
    imout = np.zeros((img.shape[0]*2, img.shape[1]*3), dtype=np.uint8)
    for i in range(5):
        y_pos, x_pos = math.floor(i/3)*img.shape[0], i%3*img.shape[0]
        imout[int(y_pos):int((y_pos+img.shape[0])), int(x_pos):int((x_pos+img.shape[0]))] = img[:,:,i]
        imout[int(y_pos):int(y_pos)+2,:] = 1
        imout[:,int(x_pos):int(x_pos)+2] = 1
    plt.imshow(imout)
    plt.show()
    
def multi_resize(img_mask, image_rows=img_rows, image_cols=img_cols, classes=classes):
    imout = np.ndarray((image_rows, image_cols, classes), dtype=np.uint8)
    for i in range(classes):
        imout[:,:,i] = resize(img_mask[:,:,i].astype(np.float32), (img_rows, img_cols), mode='reflect')
    return imout

def create_train_data(images, classes=5):
    total = len(images) 
    imgs = np.ndarray((total, img_rows, img_cols, 3), dtype=np.float32)
    imgs_mask = np.ndarray((total, img_rows, img_cols, classes), dtype=np.uint8)
    i = 0
    print('-'*30)
    print('Creating training images...')
    print('-'*30)
    for image_mask_name in images:
        image_name = image_mask_name.split('.')[0] + '.jpg'
        img = imread(os.path.join(train_data_path, image_name), as_grey=False)
        img_mask = np.load(os.path.join(mask_data_path,'train', image_mask_name))
        img = resize(img, (img_rows, img_cols), mode='reflect')
        img_mask = multi_resize(img_mask)

        img = np.array([img])
        img_mask = np.array([img_mask])

        imgs[i] = img
        imgs_mask[i] = img_mask

        if i % 500 == 0:
            print('Done: {0}/{1} images'.format(i, total))
        i += 1
    print('Loading done.')
    return imgs, imgs_mask

def test_generator(df, input_folder, batch_size = 16):
    n = df.shape[0]
    batch_index = 0
    while 1:
        current_index = batch_index * batch_size
        if n >= current_index + batch_size:
            current_batch_size = batch_size
            batch_index += 1    
        else:
            current_batch_size = n - current_index
            batch_index = 0        
        batch_df = df[current_index:current_index+current_batch_size]
        batch_x = np.zeros((batch_df.shape[0], img_rows, img_cols, 3)).astype('float32')
        i = 0
        for index,row in batch_df.iterrows():
            img = imread(os.path.join(data_path, input_folder, row[0]+'.jpg'), as_grey=False)
            img = resize(img, (img_rows, img_cols), mode='reflect')
            x = np.array([img])
            x -= mean
            x /= std
            batch_x[i] = x
            i += 1
        if batch_index%300 == 0: print(batch_index)
        yield(batch_x.transpose(0, 3, 1, 2))

def testchk_generator(df, input_folder, batch_size = 16):
    n = df.shape[0]
    batch_index = 0
    while 1:
        current_index = batch_index * batch_size
        if n >= current_index + batch_size:
            current_batch_size = batch_size
            batch_index += 1    
        else:
            current_batch_size = n - current_index
            batch_index = 0        
        batch_df = df[current_index:current_index+current_batch_size]
        batch_x = np.zeros((batch_df.shape[0], img_rows, img_cols, 3)).astype('float32')
        i = 0
        for index,row in batch_df.iterrows():
            img = imread(os.path.join(data_path, input_folder, row[0]), as_grey=False)
            img = resize(img, (img_rows, img_cols), mode='reflect')
            x = np.array([img])
            x -= mean
            x /= std
            batch_x[i] = x
            i += 1
        if batch_index%300 == 0: print(batch_index)
        return(batch_x.transpose(0, 3, 1, 2))

# %%
images = os.listdir(os.path.join(mask_data_path,'train'))
images = [i for i in images if '.npy' in i]
img_folds = [[i for i in images if int(i.split('_')[0])%2==0], [i for i in images if int(i.split('_')[0])%2==1]]
len(images)
# Out:
# 7973

# %%
vggTest = pd.read_csv('../coords/vggTestPreds2604.csv')
idx = vggTest.groupby(['img'])['predSeal'].transform(max) == vggTest['predSeal']
vggTest = vggTest[idx]
vggTest = vggTest[vggTest['predSeal']>0.6].reset_index(drop=True)
imagesTst = vggTest.img.unique().tolist()
print(len(imagesTst))
imagesTst[:5]
# Out:
# 156529
# ['11710_62', '17920_13', '7121_51', '15778_83', '17146_84']

# %%
def test_generator(df, input_folder, batch_size = 16):
    n = df.shape[0]
    batch_index = 0
    while 1:
        current_index = batch_index * batch_size
        if n >= current_index + batch_size:
            current_batch_size = batch_size
            batch_index += 1    
        else:
            current_batch_size = n - current_index
            batch_index = 0        
        batch_df = df[current_index:current_index+current_batch_size]
        batch_x = np.zeros((batch_df.shape[0], img_rows, img_cols, 3)).astype('float32')
        i = 0
        for index,row in batch_df.iterrows():
            img = imread(os.path.join(data_path, input_folder, row[0]+'.jpg'), as_grey=False)
            img = resize(img, (img_rows, img_cols), mode='reflect')
            x = np.array([img])
            x -= mean
            x /= std
            batch_x[i] = x
            i += 1
        yield(batch_x.transpose(0, 3, 1, 2))

# %%
for fold in range(2):
    print('-'*30)
    print('Upload data...')
    print('-'*30)
    imgs_train, imgs_mask_train = create_train_data(img_folds[fold], classes=5)
    imgs_train = preprocess_img(imgs_train)

    print('-'*30)
    print('Process data...')
    print('-'*30)
    imgs_mask_train = preprocess_mask(imgs_mask_train)
    imgs_train = imgs_train.astype('float32')
    mean = np.mean(imgs_train)  # mean for data centering
    std = np.std(imgs_train)  # std for data normalization

    imgs_train -= mean
    imgs_train /= std

    imgs_train = imgs_train[:,:,:,:,0]
    imgs_mask_train = imgs_mask_train[:,:,:,:,0]

    #print(imgs_mask_train[100].shape)
    #print(imgs_mask_train[100].dtype)
    #show_mask(imgs_mask_train[100])

    #del model
    print('-'*30)
    print('Creating and compiling model...')
    print('-'*30)
    model = create_model()
    model_checkpoint = ModelCheckpoint('weights_classBoost_fold'+str(fold)+'.h5', monitor='val_loss', save_best_only=True)
    model.load_weights('weights_class_fold'+str(fold)+'.h5')
    
    print('-'*30)
    print('Fitting model...')
    print('-'*30)
    optim = Adam(lr=.001)
    model.compile(optimizer=optim, loss=dice_coef_loss, metrics=[dice_coef])
    model.fit(imgs_train.transpose(0, 3, 1, 2), imgs_mask_train.transpose(0, 3, 1, 2), batch_size=batch_size, 
              verbose=1, shuffle=True, nb_epoch=nb_epoch,
              validation_split=0.2,
              callbacks=[model_checkpoint])

    print('-'*30)
    print('Predicting masks...')
    print('-'*30)
    imgs_test, tmp  = create_train_data(img_folds[abs(fold-1)], classes=5)
    imgs_test = preprocess_img(imgs_test)
    del tmp
    gc.collect()

    imgs_test -= mean
    imgs_test /= std
    imgs_test = imgs_test[:,:,:,:,0]

    print('-'*30)
    print('Predicting masks on test data...')
    print('-'*30)
    imgs_mask_test = model.predict(imgs_test.transpose(0, 3, 1, 2), batch_size=16, verbose=1)
    imgs_mask_test = imgs_mask_test.transpose(0, 2, 3, 1).astype(np.uint8)

    print('-' * 30)
    print('Saving predicted masks to files...')
    print('-' * 30)
    pred_dir = os.path.join(mask_data_path, 'traincv')
    if not os.path.exists(pred_dir):
        os.mkdir(pred_dir)
    for image, image_id in zip(imgs_mask_test, img_folds[abs(fold-1)]):
        f = gzip.GzipFile(os.path.join(pred_dir, image_id.split('.')[0]+".npy.gz"), "w")
        np.save(file=f, arr=image)
        # np.save(os.path.join(pred_dir, image_id), image)
    c = 0
    chunk_list = chunks(imagesTst, 1000)
    for img_chunk in chunk_list:
        test_df = pd.DataFrame(img_chunk, columns = ['img'])
        c += 1
        print('-'*30)
        print('Predicting masks on test data..., chunk...' + str(c))
        print('-'*30)
        imgs_mask_test = model.predict_generator(test_generator(test_df, 'JPEGImagesTest'),  
                                                 val_samples = test_df.shape[0])
        imgs_mask_test = imgs_mask_test.transpose(0, 2, 3, 1).astype(np.uint8)

        print('-' * 30)
        print('Saving predicted masks to files...')
        print('-' * 30)
        pred_dir = os.path.join(mask_data_path, 'test_fold'+str(fold))
        if not os.path.exists(pred_dir):
            os.mkdir(pred_dir)
        for image, image_id in zip(imgs_mask_test, img_chunk):
            f = gzip.GzipFile(os.path.join(pred_dir, image_id+".npy.gz"), "w")
            np.save(file=f, arr=image)
# Out:
# ------------------------------
# Upload data...
# ------------------------------
# ------------------------------
# Creating training images...
# ------------------------------
# Done: 0/4027 images
# Done: 500/4027 images
# Done: 1000/4027 images
# Done: 1500/4027 images
# Done: 2000/4027 images
# Done: 2500/4027 images
# Done: 3000/4027 images
# Done: 3500/4027 images
# Done: 4000/4027 images
# Loading done.
# ------------------------------
# Process data...
# ------------------------------
# ------------------------------
# Creating and compiling model...
# ------------------------------
# ------------------------------
# Fitting model...
# ------------------------------
# Train on 3221 samples, validate on 806 samples
# Epoch 1/5
# 3221/3221 [==============================] - 953s - loss: -0.6019 - dice_coef: 0.6019 - val_loss: -0.5245 - val_dice_coef: 0.5245
# Epoch 2/5
# 3221/3221 [==============================] - 951s - loss: -0.6192 - dice_coef: 0.6192 - val_loss: -0.5177 - val_dice_coef: 0.5177
# Epoch 3/5
# 3221/3221 [==============================] - 955s - loss: -0.6244 - dice_coef: 0.6244 - val_loss: -0.5942 - val_dice_coef: 0.5942
# Epoch 4/5
# 3221/3221 [==============================] - 954s - loss: -0.6310 - dice_coef: 0.6310 - val_loss: -0.6120 - val_dice_coef: 0.6120
# Epoch 5/5
# 3221/3221 [==============================] - 951s - loss: -0.6444 - dice_coef: 0.6444 - val_loss: -0.6088 - val_dice_coef: 0.6088
# ------------------------------
# Predicting masks...
# ------------------------------
# ------------------------------
# Creating training images...
# ------------------------------
# Done: 0/3946 images
# Done: 500/3946 images
# Done: 1000/3946 images
# Done: 1500/3946 images
# Done: 2000/3946 images
# Done: 2500/3946 images
# Done: 3000/3946 images
# Done: 3500/3946 images
# Loading done.
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# 3946/3946 [==============================] - 307s
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...1
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...2
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...3
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...4
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...5
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...6
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...7
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...8
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...9
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...10
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...11
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...12
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...13
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...14
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...15
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...16
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...17
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...18
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...19
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...20
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...21
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...22
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...23
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...24
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...25
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...26
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...27
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...28
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...29
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...30
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...31
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...32
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...33
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...34
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...35
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...36
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...37
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...38
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...39
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...40
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...41
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...42
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...43
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...44
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...45
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...46
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...47
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...48
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...49
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...50
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...51
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...52
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...53
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...54
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...55
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...56
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...57
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...58
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...59
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...60
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...61
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...62
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...63
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...64
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...65
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...66
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...67
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...68
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...69
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...70
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...71
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...72
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...73
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...74
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...75
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...76
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...77
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...78
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...79
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...80
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...81
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...82
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...83
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...84
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...85
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...86
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...87
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...88
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...89
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...90
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...91
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...92
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...93
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...94
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...95
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...96
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...97
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...98
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...99
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...100
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...101
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...102
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...103
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...104
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...105
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...106
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...107
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...108
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...109
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...110
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...111
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...112
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...113
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...114
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...115
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...116
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...117
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...118
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...119
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...120
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...121
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...122
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...123
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...124
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...125
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...126
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...127
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...128
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...129
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...130
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...131
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...132
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...133
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...134
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...135
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...136
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...137
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...138
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...139
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...140
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...141
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...142
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...143
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...144
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...145
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...146
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...147
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...148
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...149
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...150
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...151
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...152
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...153
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...154
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...155
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...156
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...157
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Upload data...
# ------------------------------
# ------------------------------
# Creating training images...
# ------------------------------
# Done: 0/3946 images
# Done: 500/3946 images
# Done: 1000/3946 images
# Done: 1500/3946 images
# Done: 2000/3946 images
# Done: 2500/3946 images
# Done: 3000/3946 images
# Done: 3500/3946 images
# Loading done.
# ------------------------------
# Process data...
# ------------------------------
# ------------------------------
# Creating and compiling model...
# ------------------------------
# ------------------------------
# Fitting model...
# ------------------------------
# Train on 3156 samples, validate on 790 samples
# Epoch 1/5
# 3156/3156 [==============================] - 931s - loss: -0.5925 - dice_coef: 0.5925 - val_loss: -0.5729 - val_dice_coef: 0.5729
# Epoch 2/5
# 3156/3156 [==============================] - 931s - loss: -0.6059 - dice_coef: 0.6059 - val_loss: -0.5722 - val_dice_coef: 0.5722
# Epoch 3/5
# 3156/3156 [==============================] - 930s - loss: -0.6139 - dice_coef: 0.6139 - val_loss: -0.4613 - val_dice_coef: 0.4613
# Epoch 4/5
# 3156/3156 [==============================] - 934s - loss: -0.6200 - dice_coef: 0.6200 - val_loss: -0.5879 - val_dice_coef: 0.5879
# Epoch 5/5
# 3156/3156 [==============================] - 934s - loss: -0.6262 - dice_coef: 0.6262 - val_loss: -0.5720 - val_dice_coef: 0.5720
# ------------------------------
# Predicting masks...
# ------------------------------
# ------------------------------
# Creating training images...
# ------------------------------
# Done: 0/4027 images
# Done: 500/4027 images
# Done: 1000/4027 images
# Done: 1500/4027 images
# Done: 2000/4027 images
# Done: 2500/4027 images
# Done: 3000/4027 images
# Done: 3500/4027 images
# Done: 4000/4027 images
# Loading done.
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# 4027/4027 [==============================] - 313s
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...1
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...2
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...3
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...4
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...5
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...6
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...7
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...8
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...9
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...10
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...11
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...12
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...13
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...14
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...15
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...16
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...17
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...18
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...19
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...20
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...21
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...22
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...23
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...24
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...25
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...26
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...27
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...28
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...29
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...30
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...31
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...32
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...33
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...34
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...35
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...36
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...37
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...38
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...39
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...40
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...41
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...42
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...43
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...44
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...45
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...46
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...47
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...48
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...49
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...50
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...51
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...52
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...53
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...54
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...55
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...56
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...57
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...58
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...59
# ------------------------------
# ...
# ------------------------------
# Predicting masks on test data..., chunk...80
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...81
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...82
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...83
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...84
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...85
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...86
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...87
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...88
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...89
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...90
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...91
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...92
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...93
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...94
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...95
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...96
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...97
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...98
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...99
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...100
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...101
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...102
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...103
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...104
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...105
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...106
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...107
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...108
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...109
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...110
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...111
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...112
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...113
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...114
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...115
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...116
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...117
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...118
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...119
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...120
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...121
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...122
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...123
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...124
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...125
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...126
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...127
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...128
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...129
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...130
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...131
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...132
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...133
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...134
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...135
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...136
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...137
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...138
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...139
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...140
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...141
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...142
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...143
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...144
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...145
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...146
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...147
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...148
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...149
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...150
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...151
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...152
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...153
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...154
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...155
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...156
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# ------------------------------
# Predicting masks on test data..., chunk...157
# ------------------------------
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
